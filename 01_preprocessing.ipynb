# %% [markdown]
# ## 전처리 연습(Tokenize, Cleansing&Normalization, Stemming&Lemmatization)

# %% [markdown]
# 1. 데이터셋을 찾는다. (텍스트 데이터셋, 만들어진 데이터셋, 크롤링 등등)
# 2. 전처리(오늘 배운 내용)
#     2-1. 의미가 있는 단어(개별적인 단어로만 구성되어 있는 데이터셋이면 안됨 -> 나중에 유사성을 사용할 거기 때문) ex. 말뭉치 찾기
#     - -> 의미가 있는 단어 단위로 vocabulary
#     2-2. corpus를 가지고 와서 토큰화 + 전처리 -> 문장 단위로 다시 묶어도 됨
#     - corpus의 종류는 다 상관 없음
#     - (ex. 사이 사이에 있는 불필요한 특수 문자, 이모지 등 / 링크나 이미지에 대한 소스가 포함된 것도 전처리, 문장만 가져오기)

# %%
with open('KETI_대화데이터_일상_오피스.txt', 'r', encoding='utf-8') as f:
    lines=f.readlines()     # 파일의 모든 줄을 읽어서 리스트로 저장
for line in lines:  # 각 줄을 순회하면서 출력
    print(line) # 줄바꿈이 포함된 상태로 출력
# Out:
# 1	﻿좋은 아침.
#
# 2	안녕하세요.
#
# 1	좋은 아침.
#
# 2	반갑습니다.
#
# 1	좋은 아침.
#
# 2	좋은 아침이에요.
#
# 1	좋은 아침.
#
# 2	간밤에 별일 없으셨죠?
#
# 1	좋은 아침.
#
# 2	안녕하시렵니까?
#
# 1	좋은 아침.
#
# 2	안녕하세요!
#
# 1	좋은 아침.
#
# 2	안녕하세요?
#
# 1	굿 모닝.
#
# 2	안녕하세요.
#
# 1	굿 모닝.
#
# 2	반갑습니다.
#
# 1	굿 모닝.
#
# 2	좋은 아침이에요.
#
# 1	굿 모닝.
#
# 2	간밤에 별일 없으셨죠?
#
# 1	굿 모닝.
#
# 2	안녕하시렵니까?
#
# 1	굿 모닝.
#
# 2	안녕하세요!
#
# 1	굿 모닝.
#
# 2	안녕하세요?
#
# 1	안녕.
#
# 2	안녕하세요.
#
# 1	안녕.
#
# 2	반갑습니다.
#
# 1	안녕.
#
# 2	좋은 아침이에요.
#
# 1	안녕.
#
# 2	간밤에 별일 없으셨죠?
#
# 1	안녕.
#
# 2	안녕하시렵니까?
#
# 1	안녕.
#
# 2	안녕하세요!
#
# 1	안녕.
#
# 2	안녕하세요?
#
# 1	안녕 컴패니언.
#
# 2	안녕하세요.
#
# 1	안녕 컴패니언.
#
# 2	반갑습니다.
#
# 1	안녕 컴패니언.
#
# 2	좋은 아침이에요.
#
# 1	안녕 컴패니언.
#
# 2	간밤에 별일 없으셨죠?
#
# 1	안녕 컴패니언.
#
# 2	안녕하시렵니까?
#
# 1	안녕 컴패니언.
#
# 2	안녕하세요!
#
# 1	안녕 컴패니언.
#
# 2	안녕하세요?
#
# 1	고마워.
#
# 2	천만에요.
#
# 1	고맙다.
#
# 2	천만에요.
#
# 1	고마워, 덕분에.
#
# 2	천만에요.
#
# 1	고마워.
#
# 2	아니에요.
#
# 1	고맙다.
#
# 2	아니에요.
#
# 1	고마워, 덕분에.
#
# 2	아니에요.
#
# 1	고마워.
#
# 2	별 말씀을요.
#
# 1	고맙다.
#
# 2	별 말씀을요.
#
# 1	고마워, 덕분에.
#
# 2	별 말씀을요.
#
# 1	그래, 고마워.
# ...

# %%
import nltk
nltk.download('punkt')      # 토큰화에 필요한 데이터
nltk.download('punkt_tab')  # punkt의 추가 테이블
nltk.download('stopwords')  # 불용어 리스트
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from collections import Counter

text = load_keti_df

load_keti_df=[]
word_counts=Counter(tokens)

filtered_tokens= [token for token in tokens if word_counts[token] >= 2]
filtered_tokens

tokens=word_tokenize(' '.join(load_keti_data('KETI_대화데이터_일상_오피스.txt')))

filtered_tokens=[token for token in tokens if len(token) > 2]
filtered_tokens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 from nltk.tokenize import word_tokenize
#       2 from collections import Counter
# ----> 4 text = load_keti_df
#       6 load_keti_df=[]
#       7 word_counts=Counter(tokens)
#
# NameError: name 'load_keti_df' is not defined

# %%
import nltk

text = load_keti_data('KETI_대화데이터_일상_오피스.txt')
# nltk 리소스 다운로드
nltk.download('punkt')      # 토큰화에 필요한 데이터
nltk.download('punkt_tab')  # punkt의 추가 테이블
nltk.download('stopwords')  # 불용어 리스트
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Playdata\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#토큰화
from konlpy.tag import Okt
import re

text=load_keti_data
okt = Okt()

ko_stopwords = ["은", "는", "이", "가", "을", "를", "와", "과", "에", "의", "으로", "나", "내", "우리", "들"]

preprocessed_texts = []

for text in text:
    tokens = okt.morphs(text, stem=True)                                        # 토큰화 및 어간 추출
    tokens = [token for token in tokens if token not in ko_stopwords]           # ko_stopwords (불용어 처리)
    tokens = [token for token in tokens if not re.search(r'[\s.,;:?~]', token)] # 정제 -> 공백문자 . , ; : ? ~
    preprocessed_texts.append(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 from konlpy.tag import Okt
#       3 import re
# ----> 5 text=load_keti_data
#       6 okt = Okt()
#       8 ko_stopwords = ["은", "는", "이", "가", "을", "를", "와", "과", "에", "의", "으로", "나", "내", "우리", "들"]
#
# NameError: name 'load_keti_data' is not defined
